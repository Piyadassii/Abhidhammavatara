# %%
from collatex import *

# %%
collation = Collation()

# %%
witness_PTS = open( "/Users/piya/Documents/Workshop/The first chapter for collation/PTS the first chaper for collation.txt", encoding='utf-8' ).read()
witness_CS = open( "/Users/piya/Documents/Workshop/The first chapter for collation/CS the first chaper for collation.txt", encoding='utf-8' ).read()
witness_G = open( "/Users/piya/Documents/Workshop/The first chapter for collation/RAS the first chaper for collation.txt", encoding='utf-8' ).read()
witness_A = open( "/Users/piya/Documents/Workshop/The first chapter for collation/A the first chaper for collation.txt", encoding='utf-8' ).read()
witness_B = open( "/Users/piya/Documents/Workshop/The first chapter for collation/B the first chaper for collation.txt", encoding='utf-8' ).read()
witness_I = open( "/Users/piya/Documents/Workshop/The first chapter for collation/I the first chaper for collation.txt", encoding='utf-8' ).read()
witness_C = open( "/Users/piya/Documents/Workshop/The first chapter for collation/C the first chaper for collation.txt", encoding='utf-8' ).read()
witness_D = open( "/Users/piya/Documents/Workshop/The first chapter for collation/D the first chaper for collation.txt", encoding='utf-8' ).read()
witness_E = open( "/Users/piya/Documents/Workshop/The first chapter for collation/E the first chaper for collation.txt", encoding='utf-8' ).read()
witness_F = open( "/Users/piya/Documents/Workshop/The first chapter for collation/F the first chaper for collation.txt", encoding='utf-8' ).read()
witness_H = open( "/Users/piya/Documents/Workshop/The first chapter for collation/H the first chaper for collation.txt", encoding='utf-8' ).read()
witness_K = open( "/Users/piya/Documents/Workshop/The first chapter for collation/K the first chaper for collation.txt", encoding='utf-8' ).read()

# %%
collation.add_plain_witness( "PTS", witness_PTS)
collation.add_plain_witness( "CS", witness_CS)
collation.add_plain_witness( "G", witness_G)
collation.add_plain_witness( "A", witness_A)
collation.add_plain_witness( "B", witness_B)
collation.add_plain_witness( "I", witness_I)
collation.add_plain_witness( "C", witness_C)
collation.add_plain_witness( "D", witness_D)
collation.add_plain_witness( "E", witness_E)
collation.add_plain_witness( "F", witness_F)
collation.add_plain_witness( "H", witness_H)
collation.add_plain_witness( "K", witness_K)

# %%
alignment_table = collate(collation, output='html2')
# Out:
# <TABLE border="1" style="border: 1px solid #000000; border-collapse: collapse;" cellpadding="4">
#  <TR>
#   <TH>PTS</TH>
#   <TH>CS</TH>
#   <TH>G</TH>
#   <TH>A</TH>
#   <TH>B</TH>
#   <TH>I</TH>
#   <TH>C</TH>
#   <TH>D</TH>
#   <TH>E</TH>
#   <TH>F</TH>
#   <TH>H</TH>
#   <TH>K</TH>
#  </TR>
#  <TR>
#   <TD bgcolor="00FFFF">12</TD>
#   <TD bgcolor="00FFFF">12</TD>
#   <TD bgcolor="00FFFF">12</TD>
#   <TD bgcolor="00FFFF">12</TD>
#   <TD bgcolor="00FFFF">12</TD>
#   <TD bgcolor="00FFFF">12</TD>
#   <TD bgcolor="00FFFF">12</TD>
#   <TD bgcolor="00FFFF">12</TD>
#   <TD bgcolor="00FFFF">12</TD>
#   <TD bgcolor="00FFFF">12</TD>
#   <TD bgcolor="00FFFF">12</TD>
#   <TD bgcolor="00FFFF">12</TD>
#  </TR>
#  <TR>
#   <TD bgcolor="FF0000">uddānato</TD>
#   <TD bgcolor="FF0000">uddānato</TD>
#   <TD bgcolor="FF0000">udānato</TD>
#   <TD bgcolor="FF0000">uddānato</TD>
#   <TD bgcolor="FF0000">uddānato</TD>
#   <TD bgcolor="FF0000">udānato</TD>
#   <TD bgcolor="FF0000">udānato</TD>
# ...

# %%
graph = collate(collation, output='svg')
